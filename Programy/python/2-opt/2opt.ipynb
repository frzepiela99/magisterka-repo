# %%
import time
import numpy as np

N = 0
M = 0
Ptr = []
W = []
Route = []
Ahead = I = I1 = I2 = Index = J = J1 = J2 = Last = Limit = Max = Max1 = Next = S1 = S2 = T1 = T2 = 0
Tweight = 0
TotalWeight = 0  # Zmienna do przechowywania sumy wag wszystkich krawędzi

def initialization():
    global N, M, Ptr, Route, W, Tweight, TotalWeight
    with open("C:\\Users\\mcmys\\OneDrive\\Pulpit\\magisterka repo\\TWOOPT\\edges1000.in", "r") as file:
        N, M = map(int, file.readline().split())
        Ptr = [0] * (N + 1)
        Route = [0] * (N + 1)
        W = np.zeros((N + 1, N + 1), dtype=int)

        for _ in range(M):
            X, Y, Temp = map(int, file.readline().split())
            W[X][Y] = Temp
            W[Y][X] = Temp
            TotalWeight += Temp  # Dodaj wagę krawędzi do całkowitej sumy wag

    for i in range(1, N + 1):
        Route[i] = i
        W[i][i] = 0
    for i in range(1, N):
        Tweight += W[i][i + 1]
    Tweight += W[N][1]

def calculations():
    global Ptr, Route, Tweight, Max, I1, S1, S2, T1, T2, Max1
    for I in range(1, N):
        Ptr[Route[I]] = Route[I + 1]
    Ptr[Route[N]] = Route[1]
    while True:
        Max = 0
        I1 = 1
        for I in range(1, N - 1):
            Limit = N if I != 1 else N - 1
            I2 = Ptr[I1]
            J1 = Ptr[I2]
            for J in range(I + 2, Limit + 1):
                J2 = Ptr[J1]
                Max1 = W[I1][I2] + W[J1][J2] - (W[I1][J1] + W[I2][J2])
                if Max1 > Max:
                    S1, S2, T1, T2 = I1, I2, J1, J2
                    Max = Max1
                J1 = J2
            I1 = I2
        if Max <= 0:
            break
        Ptr[S1] = T1
        Next = S2
        Last = T2
        while Next != T2:
            Ahead = Ptr[Next]
            Ptr[Next] = Last
            Last = Next
            Next = Ahead
        Tweight -= Max
    
    Index = 1
    for I in range(1, N + 1):
        Route[I] = Index
        Index = Ptr[Index]

def main():
    start = time.time()  # Rozpocznij pomiar czasu

    initialization()
    print("Displaying a portion of the weight matrix for verification:")
    for k in range(1, min(10, N + 1)):
        print('\t'.join(map(str, W[k][1:min(10, N + 1)])))
    calculations()
    print("Total weight of the route:", Tweight)
    print("Route:", ' '.join(map(str, Route[1:])))
    
    EdgeSum = 0
    for i in range(1, N):
        EdgeSum += W[Route[i]][Route[i + 1]]
    EdgeSum += W[Route[N]][Route[1]]  # Dodaj ostatnią krawędź do sumy

    print("Sum of all edge lengths in the route:", EdgeSum)
    print("Sum of all edge weights in the graph:", TotalWeight)

    end = time.time()  # Zakończ pomiar czasu
    duration = (end - start) * 1000
    print("Execution time:", duration, "ms")

if __name__ == "__main__":
    main()
# Out:
# Displaying a portion of the weight matrix for verification:
# 0	39	727	260	440	864	809	374	318
# 39	0	96	205	364	473	43	82	625
# 727	96	0	738	62	786	996	784	452
# 260	205	738	0	226	148	274	157	702
# 440	364	62	226	0	390	347	527	840
# 864	473	786	148	390	0	631	292	242
# 809	43	996	274	347	631	0	999	274
# 374	82	784	157	527	292	999	0	390
# 318	625	452	702	840	242	274	390	0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 95
#      92     print("Execution time:", duration, "ms")
#      94 if __name__ == "__main__":
# ---> 95     main()
#
# Cell In[8], line 78, in main()
#      76 for k in range(1, min(10, N + 1)):
#      77     print('\t'.join(map(str, W[k][1:min(10, N + 1)])))
# ---> 78 calculations()
#      79 print("Total weight of the route:", Tweight)
#      80 print("Route:", ' '.join(map(str, Route[1:])))
#
# Cell In[8], line 52, in calculations()
#      50             S1, S2, T1, T2 = I1, I2, J1, J2
#      51             Max = Max1
# ---> 52         J1 = J2
#      53     I1 = I2
#      54 if Max <= 0:
#
# KeyboardInterrupt:
